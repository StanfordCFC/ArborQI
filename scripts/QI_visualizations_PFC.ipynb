# %% [markdown]
# # Visualization of QI Questions — PFC — 3/2018 through 11/2018
#
# Alex
#
# Here, we are visualizing responses to the QI questions at PFC for new patients at their first visit to the clinic.

# %% [markdown]
# ## Setting up the code

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from utils.file_ops import *

# %% [markdown]
# Set the clinic to be visualized here

# %%
CLINIC = 'pfc'

# %% [markdown]
# Read in the results of dataprocessing

# %%
results_dict = read_from_file('qi_results_dict_mom')

# %% [markdown]
# Set up the visualization environment

# %%
sns.set()
sns.set_style("white")
sns.set_context("notebook")

# %% [markdown]
# ## Begin visualizations

# %%
one_clinic_results = results_dict[CLINIC]

# %% [markdown]
# ### First, diabetes data

# %%
one_clinic_results['QIDiabetesA1C'].head(10)
# Out:
#             Checked  Not checked
# time_point
# 3/2018            1            0
# 4/2018            3            0
# 5/2018            1            0
# 6/2018            1            0
# 7/2018            0            0
# 8/2018            4            0
# 9/2018            0            0
# 10/2018           2            0
# 11/2018           1            0
# 12/2018           0            0

# %%
fig, ax = plt.subplots(figsize=(8,8))
sns.lineplot(data=one_clinic_results['QIDiabetes'], ax=ax, markers=True, sort=False)
plt.ylabel('Number of Patients')
plt.title('Responses to QI Diabetes at ' + CLINIC)
# Out:
# Text(0.5,1,'Responses to QI Diabetes at pfc')

# %% [markdown]
# In addition to the distribution of responses indicating whether patients have diabetes, we want to look at associated questions that we would ask patients who are positive for diabetes.

# %% [markdown]
# This cell summarizes labs/exams/referrals utilized for diabetic patients.

# %%
db_df = read_from_file('diabetes_fused')
db_df_spec = db_df[CLINIC]
db_df_spec.head(10)
# Out:
#             Total Diabetic  QIDiabetesA1C  QIDiabetesFoot  QIDiabetesOphtho  \
# time_point
# 3/2018                   3              1               1                 1
# 4/2018                   4              3               1                 1
# 5/2018                   3              1               0                 0
# 6/2018                   4              1               1                 1
# 7/2018                   2              0               1                 0
# 8/2018                   5              4               3                 3
# 9/2018                   1              0               1                 0
# 10/2018                  3              2               0                 1
# 11/2018                  2              1               1                 0
# 12/2018                  0              0               0                 0
#
#             QIDiabetesPneumovax  QIMicroalbumin
# time_point
# 3/2018                        1               1
# ...

# %% [markdown]
# This is a visualization of the labs/exams/referrals utilized for diabetic patients

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.lineplot(data=db_df_spec, markers=True, dashes=False, ax=ax, sort=False)
plt.ylabel('Patient Number')
plt.title('Diabetic Patient Quality Checks at ' + CLINIC)
# Out:
# Text(0.5,1,'Diabetic Patient Quality Checks at pfc')

# %% [markdown]
# Here, we will visualize each of the individual labs/exams/referrals evaluated in QI questions against the positive diabetic patient population

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.lineplot(data=db_df_spec[['Total Diabetic', 'QIDiabetesA1C']], markers=True, dashes=False, ax=ax, sort=False)
plt.ylabel('Patient Number')
plt.title('Diabetic Patient Quality Checks - A1C - at ' + CLINIC)
# Out:
# Text(0.5,1,'Diabetic Patient Quality Checks - A1C - at pfc')

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.lineplot(data=db_df_spec[['Total Diabetic', 'QIDiabetesFoot']], markers=True, dashes=False, ax=ax, sort=False)
plt.ylabel('Patient Number')
plt.title('Diabetic Patient Quality Checks - Foot Exam - at ' + CLINIC)
# Out:
# Text(0.5,1,'Diabetic Patient Quality Checks - Foot Exam - at pfc')

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.lineplot(data=db_df_spec[['Total Diabetic', 'QIDiabetesOphtho']], markers=True, dashes=False, ax=ax, sort=False)
plt.ylabel('Patient Number')
plt.title('Diabetic Patient Quality Checks - Eye Exam - at ' + CLINIC)
# Out:
# Text(0.5,1,'Diabetic Patient Quality Checks - Eye Exam - at pfc')

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.lineplot(data=db_df_spec[['Total Diabetic', 'QIDiabetesPneumovax']], markers=True, dashes=False, ax=ax, sort=False)
plt.ylabel('Patient Number')
plt.title('Diabetic Patient Quality Checks - Pneumovax - at ' + CLINIC)
# Out:
# Text(0.5,1,'Diabetic Patient Quality Checks - Pneumovax - at pfc')

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.lineplot(data=db_df_spec[['Total Diabetic', 'QIMicroalbumin']], markers=True, dashes=False, ax=ax, sort=False)
plt.ylabel('Patient Number')
plt.title('Diabetic Patient Quality Checks - Microalbumin - at ' + CLINIC)
# Out:
# Text(0.5,1,'Diabetic Patient Quality Checks - Microalbumin - at pfc')

# %% [markdown]
# ## In the following cells, we will visualize the remainder of the QI Questions.

# %% [markdown]
# First, we have utilization of mammograms for female patients.

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.lineplot(data=one_clinic_results['QIMammo'], ax=ax, markers=True, sort=False)
plt.ylabel('Patient Number')
plt.title('Responses to QI Mammography at '+ CLINIC)
# Out:
# Text(0.5,1,'Responses to QI Mammography at pfc')

# %% [markdown]
# This visualization demonstrates potentially subpar health maintenace for female patients — the sum of all responses is less than the number of female patients per month.

# %% [markdown]
# Now, we have utilization of pap smear utilization.

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.lineplot(data=one_clinic_results['QIPap'], ax=ax, markers=True, sort=False)
plt.ylabel('Patient Number')
plt.title('Responses to QI Pap Smear at '+ CLINIC)
# Out:
# Text(0.5,1,'Responses to QI Pap Smear at pfc')

# %% [markdown]
# ### Mental Health Questions

# %% [markdown]
# First, we can see that the QI Mental Health 1/2 questions are only utilized for very few patients.

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.lineplot(data=one_clinic_results['QIMentalHealth1'], ax=ax, markers=True, sort=False)
plt.ylabel('Patient Number')
plt.title('Responses to QI Mental Health 1 at '+ CLINIC)
# Out:
# Text(0.5,1,'Responses to QI Mental Health 1 at pfc')

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.lineplot(data=one_clinic_results['QIMentalHealth2'], ax=ax, markers=True, sort=False)
plt.ylabel('Patient Number')
plt.title('Responses to QI Mental Health 2 at '+ CLINIC)
# Out:
# Text(0.5,1,'Responses to QI Mental Health 2 at pfc')

# %% [markdown]
# In contrast to the previous mental health questions, we can see that PHQ1/2 questions are being utilized quite extensively.

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.lineplot(data=one_clinic_results['QIPHQ1'], ax=ax, markers=True, sort=False)
plt.ylabel('Patient Number')
plt.title('Responses to QI PHQ1 at '+ CLINIC)
# Out:
# Text(0.5,1,'Responses to QI PHQ1 at pfc')

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.lineplot(data=one_clinic_results['QIPHQ2'], ax=ax, markers=True, sort=False)
plt.ylabel('Patient Number')
plt.title('Responses to QI PHQ 2 at '+ CLINIC)
# Out:
# Text(0.5,1,'Responses to QI PHQ 2 at pfc')
