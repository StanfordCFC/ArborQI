# %% [markdown]
# # Imports

# %%
import pandas
import numpy as np
import matplotlib as plt
from __future__ import print_function
from utils.file_ops import *
# %matplotlib inline

# %% [markdown]
# # Import CSV and Pivot on Patient Number

# %%
path3 = 'data/QIdudes.csv'
data = returnDF(path3)

arbor_data = data[data['LocationName'] == 'ARBOR']
pfc_data = data[data['LocationName'] == 'PFC']

arbor_pivot = arbor_data.pivot_table(index='PatientNumber',columns='Note PropertyName',values='Note PropertyValue', aggfunc='first')
pfc_pivot = pfc_data.pivot_table(index='PatientNumber',columns='Note PropertyName',values='Note PropertyValue', aggfunc='first')

arbor_pivot.head(5)

pfc_pivot.head(5)
# Out:
# preparing to open csv at: data/QIdudes.csv
# done preparing dataframe
# Note PropertyName  19yo HIVTestAgreedToTest HIVTestLackOfPercRisk HIVTestNA  \
# PatientNumber
# N0001928           None                None                  None      None
# N0003498           None                None                  None      None
# N0003968           None                None                  None      None
# N0007450           None                None                  None      None
# N0009647           None                None                  None      None
#
# Note PropertyName PFCHepAreq PFCHepBreq QIDiabetes QIDiabetesA1C  \
# PatientNumber
# N0001928                None       None         No          None
# N0003498                None       None         No          None
# N0003968                None       None         No          None
# N0007450                None       None         No          None
# N0009647                None       None        Yes          True
#
# Note PropertyName QIDiabetesFoot QIDiabetesOphtho    ...       SHxSexualAct  \
# PatientNumber                                        ...
# N0001928                    None             None    ...     Not Questioned
# N0003498                    None             None    ...               None
# N0003968                    None             None    ...     Not Questioned
# N0007450                    None             None    ...                 No
# N0009647                    True             True    ...     Not Questioned
#
# Note PropertyName SHxSmokeReason       SHxSmoker StudentAssessment  \
# PatientNumber
# N0001928                    None  Not Questioned              None
# N0003498                    None            None              None
# N0003968                    None  Not Questioned              None
# N0007450                    None              No              None
# N0009647                    None             Yes              None
#
# Note PropertyName StudentPlan StudentSummaryText WriteStudentAssessment  \
# PatientNumber
# N0001928                 None               None                   None
# N0003498                 None               None                   None
# N0003968                 None               None                   None
# N0007450                 None               None                   None
# N0009647                 None               None                   None
#
# Note PropertyName WriteStudentPlan income uninsured
# PatientNumber
# N0001928                      None   None      None
# N0003498                      None   None      None
# N0003968                      None   None      None
# N0007450                      None   None      None
# N0009647                      None   None      None
#
# [5 rows x 47 columns]

# %% [markdown]
# # Generate Distributions of Appropriate Columns

# %%
qi_columns = ['QIDiabetes', 'QIDiabetesA1C', 'QIDiabetesFoot', 'QIDiabetesOphtho', 'QIDiabetesPneumovax', 'QIDiabetesReason',
              'QIMHReason1', 'QIMHReason2', 'QIMammo', 'QIMammoReason', 'QIMentalHealth1', 'QIMentalHealth2', 'QIMicroalbumin',
              'QIPHQ1', 'QIPHQ2', 'QIPHQ2Reason1', 'QIPHQ2Reason2', 'QIPap', 'QIPapReason']

def print_qisummary(key_value,df):
    if key_value in df:
        print(df.groupby(key_value).size())
    else:
        print(key_value + ': No records found (assume 0)')

# %% [markdown]
# # Diabetes Management

# %%
print('Arbor\n====================')
print_qisummary('QIDiabetes',arbor_pivot)
print()
print_qisummary('QIDiabetesA1C',arbor_pivot)
print()
print_qisummary('QIMicroalbumin',arbor_pivot)
print()
print_qisummary('QIDiabetesFoot',arbor_pivot)
print()
print_qisummary('QIDiabetesOphtho',arbor_pivot)
print()
print_qisummary('QIDiabetesPneumovax',arbor_pivot)
print()
print_qisummary('QIDiabetesReason',arbor_pivot)

print('\n')

print('PFC\n====================')
print_qisummary('QIDiabetes',pfc_pivot)
print()
print_qisummary('QIDiabetesA1C',pfc_pivot)
print()
print_qisummary('QIDiabetesMicroalbumin',pfc_pivot)
print()
print_qisummary('QIDiabetesFoot',pfc_pivot)
print()
print_qisummary('QIDiabetesOphtho',pfc_pivot)
print()
print_qisummary('QIDiabetesPneumovax',pfc_pivot)
print()
print_qisummary('QIDiabetesReason',pfc_pivot)
# Out:
# Arbor
# ====================
# QIDiabetes
# No     132
# Yes     11
# dtype: int64
#
# QIDiabetesA1C
# True    9
# dtype: int64
#
# QIMicroalbumin
# True    5
# dtype: int64
#
# QIDiabetesFoot
# True    2
# dtype: int64
#
# QIDiabetesOphtho: No records found (assume 0)
#
# QIDiabetesPneumovax: No records found (assume 0)
#
# QIDiabetesReason
# Foot exam and eye referral at next visit                                                                                      1
# Foot exam and optho referral to be placed when established with PCP (referral placed) for continuity of care                  1
# Not pertinent to cc                                                                                                           1
# Patient does not live in the USA and could not be here for opthalmolgy visit                                                  1
# Patient followed by PCP in Mexico, had A1C and microalbumin within past 3 months                                              1
# Patient has PCP in Nepal from whom he receives medications and comprehensive care (ophtalmology). He is already on an ARB.    1
# Patient to be set up with primary care as well as with podiatry.                                                              1
# Pt instructed to go to ED, addressed other concerns today                                                                     1
# Time                                                                                                                          1
# dtype: int64
#
#
# PFC
# ====================
# QIDiabetes
# No     182
# Yes     22
# dtype: int64
#
# QIDiabetesA1C
# True    16
# dtype: int64
#
# QIDiabetesMicroalbumin: No records found (assume 0)
#
# QIDiabetesFoot
# True    12
# dtype: int64
#
# QIDiabetesOphtho
# True    14
# dtype: int64
#
# QIDiabetesPneumovax
# True    4
# dtype: int64
#
# QIDiabetesReason
# Did not receive the other services as patient refused                                                                               1
# Going back to China in 3 days                                                                                                       1
# Ophtho exam done within the past year.                                                                                              1
# Patient to follow up in 2 weeks, will order at that time as patient overwhelmed with multiple new medication changes at this vis    1
# Plan for microalbumin next week at lab appointment                                                                                  1
# Pneumovax not available                                                                                                             1
# Pneumovax out                                                                                                                       1
# Referral to Eye clinic already done.  Pneumovax not addressed                                                                       1
# Referred for pneumovax, cannot get for 2 weeks. Already had A1c checked.                                                            1
# Visiting very short term                                                                                                            1
# has had eye check in last year and renal function normal on creatinie so deferred microalbumin. PPSV23 out today                    1
# no time for foot exam or microalbumin                                                                                               1
# pt will receive in China                                                                                                            1
# dtype: int64

# %% [markdown]
# # Mental Health

# %%
print('Arbor\n====================')
print_qisummary('QIPHQ1',arbor_pivot)
print()
print_qisummary('QIPHQ2',arbor_pivot)
print()
print_qisummary('QIPHQ2Reason1',arbor_pivot)
print()
print_qisummary('QIPHQ2Reason2',arbor_pivot)
print()
print_qisummary('QIMentalHealth1',arbor_pivot)
print()
print_qisummary('QIMentalHealth2',arbor_pivot)
print()
print_qisummary('QIMHReason1',arbor_pivot)
print()
print_qisummary('QIMHReason2',arbor_pivot)

print('\n')

print('PFC\n====================')
print_qisummary('QIPHQ1',pfc_pivot)
print()
print_qisummary('QIPHQ2',pfc_pivot)
print()
print_qisummary('QIPHQ2Reason1',pfc_pivot)
print()
print_qisummary('QIPHQ2Reason2',pfc_pivot)
print()
print_qisummary('QIMentalHealth1',pfc_pivot)
print()
print_qisummary('QIMentalHealth2',pfc_pivot)
print()
print_qisummary('QIMHReason1',pfc_pivot)
print()
print_qisummary('QIMHReason2',pfc_pivot)
# Out:
# Arbor
# ====================
# QIPHQ1
# No                83
# Not Questioned    52
# Yes                8
# dtype: int64
#
# QIPHQ2
# No                85
# Not Questioned    50
# Yes                8
# dtype: int64
#
# QIPHQ2Reason1
# Adressed other acute concerns today                                                                            1
# Altered mental status                                                                                          1
# Asked about her mood, said she was feeling fine./ Denied any feelings of sadnesss/                             1
# Currently following with mental health                                                                         1
# Focused history                                                                                                1
# Language barrier                                                                                               1
# Limited Time                                                                                                   1
# Low index of suspicion                                                                                         1
# MSK clinic                                                                                                     1
# MSK clinicn                                                                                                    1
# Not related to CC                                                                                              1
# Not relevant to chief complaint                                                                                1
# Not relevant visit                                                                                             1
# Patient had much more emergency finding requiring referral to ED                                               1
# Patient was a Mandarin speaker and the interview had already taken up quite some time with the interpreter.    1
# Previously seen                                                                                                1
# Pt stated he was not feeling down or depressed.                                                                1
# addressed other patient's multiple concerns                                                                    1
# n/a                                                                                                            1
# no symptoms endorsed                                                                                           1
# not related to cc                                                                                              1
# not related to current problem                                                                                 1
# not relevent to CC, no evidence of depression                                                                  1
# seen by mental health                                                                                          1
# time constraint                                                                                                1
# time constratint                                                                                               1
# time limitations                                                                                               1
# dtype: int64
#
# QIPHQ2Reason2
# Addressed other acute concerns today                                       1
# Altered mental status                                                      1
# Currently following with mental health                                     1
# Focused history                                                            1
# Language barrier                                                           1
# Limited Time                                                               1
# Low index of suspicion                                                     1
# MSK clinic                                                                 2
# Not related to CC                                                          1
# Not relevant to chief complaint                                            1
# Not relevant visit                                                         1
# Patient had much more emergent finding reequiring referral to ED           1
# Previously seen                                                            1
# Same as above                                                              1
# n/a                                                                        1
# no symptoms endorsed                                                       1
# not related to cc                                                          1
# not related to current problem                                             1
# not relevelent to CC, no evidence of depression                            1
# patient wanted to discuss other more urgent issues                         1
# seen by mental health                                                      1
# the patient did not display any loss of interest or signs of depression    1
# time constraint                                                            2
# time limitations                                                           1
# dtype: int64
#
# QIMentalHealth1
# No    5
# dtype: int64
#
# QIMentalHealth2
# No     3
# Yes    2
# dtype: int64
#
# QIMHReason1
# Believed to be thyroid related                                                                                                      1
# Patient regularly sees a therapist and is prescribed Prozac.                                                                        1
# Pt with known history of depression and multiple SSRI trials, currently doing well. Will seek mental health eval once establishe    1
# patient wanted to discuss other more urgent issues                                                                                  1
# dtype: int64
#
# QIMHReason2
# Believed to be thyroid related                                  1
# Patient already followed by mental health at the VA             1
# Patient regularly sees a therapist and is prescribed Prozac.    1
# dtype: int64
#
#
# PFC
# ====================
# QIPHQ1
# No                155
# Not Questioned     33
# Yes                16
# dtype: int64
#
# QIPHQ2
# No                145
# Not Questioned     32
# Yes                27
# dtype: int64
#
# QIPHQ2Reason1
# Did not have time, will address in 2 weeks                                1
# Follow up                                                                 1
# Followup                                                                  1
# Forgot                                                                    1
# Language Barrier                                                          1
# Not discussed due to time limitation, will address in 2 weeks             1
# Not relevant to HPI.                                                      1
# Patient was referred to mental health after the intial visit              1
# Patient's husband recently passed away, mood will be low                  1
# Previously screened, not relevant to current visit for follow-up labs.    1
# f/U                                                                       1
# follow up                                                                 3
# n/a                                                                       7
# not related to chief complaint                                            1
# refill visit                                                              1
# she did not want an interview                                             1
# dtype: int64
#
# QIPHQ2Reason2
# Did not have time, will address in 2 weeks                                1
# F/U                                                                       1
# Follow up                                                                 1
# Followup                                                                  1
# Forgot                                                                    1
# Language Barrier                                                          1
# Not discussed due to time limitation, will address in 2 weeks             1
# Not relevant to HPI.                                                      1
# Patient was referred to mental health after the intial visit              1
# Previously screened, not relevant to current visit for follow-up labs.    1
# follow up                                                                 3
# husband just recently passed away                                         1
# n/a                                                                       7
# not related to chief complaint                                            1
# refill visit                                                              1
# she did not want an interview                                             1
# dtype: int64
#
# QIMentalHealth1
# No     4
# Yes    8
# dtype: int64
#
# QIMentalHealth2
# No     12
# Yes    11
# dtype: int64
#
# QIMHReason1
# Not interested                                             1
# Outside primary doctor responsible                         1
# Prescribed medication for low mood.                        1
# currently seeing mental health professional for therapy    1
# dtype: int64
#
# QIMHReason2
# Dr. Singh evaluated pt for mental health concerns, discussed the possibility of longer term mood stabilizing meds -- patient agr    1
# He currently has a PCP                                                                                                              1
# Not interested                                                                                                                      1
# Outside primary doctor responsible                                                                                                  1
# Patient is not interested in mental health referral at this time                                                                    1
# Prescribed medication for low mood.                                                                                                 1
# Pt. not interested in mental health at this time. Pt. was counselled that a mental health appointment was our medical recommenda    1
# Requested medications instead                                                                                                       1
# already seeing psychiatrist from primary care physician                                                                             1
# clear reversible cause of headache                                                                                                  1
# currently seeing mental health professional for therapy                                                                             1
# was following friend's diagnosis and has gotten better                                                                              1
# dtype: int64

# %% [markdown]
# # Women's Health

# %%
print('Arbor\n====================')
print_qisummary('QIPap',arbor_pivot)
print()
print_qisummary('QIPapReason',arbor_pivot)
print()
print_qisummary('QIMammo',arbor_pivot)
print()
print_qisummary('QIMammoReason',arbor_pivot)

print('\n')

print('PFC\n====================')
print_qisummary('QIPap',pfc_pivot)
print()
print_qisummary('QIPapReason',pfc_pivot)
print()
print_qisummary('QIMammo',pfc_pivot)
print()
print_qisummary('QIMammoReason',pfc_pivot)
# Out:
# Arbor
# ====================
# QIPap
# Already Received     7
# No                  16
# Not Indicated       18
# Yes                  7
# dtype: int64
#
# QIPapReason
# Focused on acute complaint, no preclinical student available so time constraints                                                    1
# None                                                                                                                                1
# Not asked                                                                                                                           1
# Patient already has private insurance.                                                                                              1
# Patient is going back on health care insurance with Kaiser in January. December was their only month without healthcare insuranc    1
# Patient reports she is waiting for medical and will then go to SUH for ongoing primary care                                         1
# Returning to China in 1 month                                                                                                       1
# Visiting US                                                                                                                         1
# Visiting from Ethiopia                                                                                                              1
# addressed other acute concerns today, will referr patient to establish care with a PCP                                              1
# obgyn not discussed                                                                                                                 1
# dtype: int64
#
# QIMammo
# Already Received     1
# No                  21
# Not Indicated        6
# Yes                  2
# dtype: int64
#
# QIMammoReason
# Acute visit for cough.                            1
# Limited Time                                      1
# MSK clinic                                        1
# No interest                                       1
# Not asked                                         1
# Not relevant to current issue, referred to PCP    1
# Patient received                                  1
# Patient to get referral to primary care           1
# Returning to China in 1 month                     1
# She was informed of womens health clinic.         1
# This is Arbor not PFC                             1
# Visiting US                                       1
# did not have time to assess                       1
# n/a                                               2
# she declined                                      1
# will need to adress next time                     1
# dtype: int64
#
#
# PFC
# ====================
# QIPap
# Already Received    10
# No                  30
# Not Indicated       18
# Yes                 27
# dtype: int64
#
# QIPapReason
# Already conducted in June 2017                                                               1
# Did not address at this visit                                                                1
# Going to get a PCP in near future.                                                           1
# Has had a pap smear within the past 3 months.                                                1
# Last pap smear 2 years ago                                                                   1
# Med refill visit, plans to establish with community PCP                                      1
# No services available.                                                                       1
# Not in age range                                                                             1
# Patient is recieving primary care in India                                                   1
# Patient received a pap smear 2 years ago.                                                    1
# Patient received in last year                                                                1
# Pt had a pap smear 2 y/o but it was inconclusive. Pt has not had a subsequent pap smear.     1
# She had a hysterectomy                                                                       1
# She refused referral to Women's Clinic                                                       1
# The patient has had a pap smear in the last 5 years.                                         1
# Will be returning to India before next WH clinic                                             1
# had one within 2 yrs                                                                         1
# n/a                                                                                          1
# not assessed in mental health visit                                                          1
# not interested                                                                               1
# not needed, in mexico ~year ago                                                              1
# not questioned                                                                               2
# patient going to China                                                                       1
# previous pap 14mo ago                                                                        1
# pt is not sexually active and has never been sexually active                                 1
# s/p hysterctomy                                                                              1
# up-to-date                                                                                   1
# dtype: int64
#
# QIMammo
# Already Received     8
# No                  26
# Not Indicated       15
# Yes                 12
# dtype: int64
#
# QIMammoReason
# Did not address at this visit                                            1
# Going back to China in 3 days                                            1
# Mamogram                                                                 1
# Never had mammogram.                                                     1
# Patient had mammogram last year and reports that results were normal     1
# Patient is recieving primary care in India                               1
# Patient received a mammo 3 years ago                                     1
# Patient received in last year                                            1
# She does not want mammo at this time                                     1
# She had 2 mastectomies                                                   1
# She receives OB/GYN check ups regulary through Kaiser                    1
# She refused referral to women's clinic                                   1
# did not have time to discuss.                                            1
# does need mammogram                                                      1
# n/a                                                                      1
# not interested                                                           1
# not questioned                                                           1
# pt going to china in 1 week                                              1
# returning to India withinin the month                                    1
# will see women's clinic                                                  1
# dtype: int64
